# %%
#import
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
#input signal
time = np.arange(0,10,0.001)
period = 4
omega0 = 2*np.pi/period
x_t = np.sin(omega0*time)/(omega0*time)
plt.plot(time,x_t)
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %%
#FT of input signal
